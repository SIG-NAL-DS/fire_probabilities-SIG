# %%
# !pip install xarray  rasterio
# Out:
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (2024.11.0)
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from xarray) (1.26.4)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.10/dist-packages (from xarray) (24.2)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.10/dist-packages (from xarray) (2.2.2)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (24.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.12.14)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from rasterio) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1->xarray) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1->xarray) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray) (1.17.0)
# Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 67.6 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.4.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !apt-get install -y gdal-bin
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   python3-gdal python3-numpy
# Suggested packages:
#   libgdal-grass python-numpy-doc python3-pytest
# The following NEW packages will be installed:
#   gdal-bin python3-gdal python3-numpy
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 5,055 kB of archives.
# After this operation, 25.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-numpy amd64 1:1.21.5-1ubuntu22.04.1 [3,467 kB]
# Get:2 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-gdal amd64 3.6.4+dfsg-1~jammy0 [1,027 kB]
# Get:3 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 gdal-bin amd64 3.6.4+dfsg-1~jammy0 [561 kB]
# Fetched 5,055 kB in 2s (2,752 kB/s)
# Selecting previously unselected package python3-numpy.
# (Reading database ... 123635 files and directories currently installed.)
# Preparing to unpack .../python3-numpy_1%3a1.21.5-1ubuntu22.04.1_amd64.deb ...
# Unpacking python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Selecting previously unselected package python3-gdal.
# Preparing to unpack .../python3-gdal_3.6.4+dfsg-1~jammy0_amd64.deb ...
# Unpacking python3-gdal (3.6.4+dfsg-1~jammy0) ...
# Selecting previously unselected package gdal-bin.
# Preparing to unpack .../gdal-bin_3.6.4+dfsg-1~jammy0_amd64.deb ...
# Unpacking gdal-bin (3.6.4+dfsg-1~jammy0) ...
# Setting up python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Setting up python3-gdal (3.6.4+dfsg-1~jammy0) ...
# Setting up gdal-bin (3.6.4+dfsg-1~jammy0) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
import ftplib
import os
import xarray as xr
import pandas as pd
import numpy as np
import rasterio
from rasterio.transform import from_bounds
from scipy.interpolate import griddata
import subprocess
from google.cloud import storage
import ee

# %%
ee.Authenticate()
# Initialize Earth Engine
ee.Initialize(project='pyregence-ee')

# %% [markdown]
# **Models**
# * ACCESS1-0
# * BCC-CSM1-1
# * BCC-CSM1-1-M
# * BNU-ESM
# * CanESM2
# * CCSM4
# * CESM1-BGC
# * CESM1-CAM5
# * CMCC-CM
# * CNRM-CM5
# * CSIRO-Mk3-6-0
# * FGOALS-G2
# * FIO-ESM
# * GFDL-CM3
# * GFDL-ESM2G
# * GFDL-ESM2M
# * GISS-E2-H-CC
# * GISS-E2-R
# * GISS-E2-R-CC
# * HadGEM2-AO
# * HadGEM2-CC
# * HadGEM2-ES
# * INMCM4
# * IPSL-CM5A-MR
# * IPSL-CM5B-LR
# * MIROC-ESM
# * MIROC-ESM-CHEM
# * MIROC5
# * MPI-ESM-LR
# * MPI-ESM-MR
# * MRI-CGCM3
# * NorESM1-M
#
# **Variables**
# - albedo
# - baseflow
# - del_SWE
# - ET
# - latent
# - longwave_net
# - pet_natveg
# - precip
# - Qair
# - rainfall
# - rel_Humid
# - runoff
# - sensible
# - shortwave_in
# - shortwave_net
# - snow_melt
# - snowfall
# - soilMoist1
# - soilMoist2
# - soilMoist3
# - sublimation_net
# - SWE
# - Tair
# - Wdew
# - windspeed

# %%
def download_model_files(model, year, variable, scenario="rcp85", local_destination=None):
    """
    Download a specific NetCDF file for a model and year from the FTP server.

    Parameters
    ----------
    model: str
        Model name (e.g., "CESM1-BGC", "CanESM2").
    year: int
        Year of the desired file.
    variable: str
        Variable to download (e.g., "ET").
    scenario: str
        Climate scenario for future projections (default: "rcp85"). "rcp45"
        Used for years after 2005.
    local_destination: str
        Destination folder to save files locally. Defaults to current working directory.

    Returns
    -------
    local_file_path: str
        Path to the downloaded file or None if the file was not found.
    """
    ftp_server = "gdo-dcp.ucllnl.org"
    base_path = "/pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28"

    # Set local destination
    if local_destination is None:
        local_destination = os.getcwd()
    if not os.path.exists(local_destination):
        os.makedirs(local_destination)

    # Connect to FTP server
    ftp = ftplib.FTP(ftp_server)
    ftp.login()
    print(f"Connected to {ftp_server}.")

    # Determine folder based on year
    if year <= 2005:
        folder_path = f"{base_path}/{model}/vic_output.historical.netcdf"
    else:
        folder_path = f"{base_path}/{model}/vic_output.{scenario}.netcdf"

    # File name for the specific year
    file_name = f"{variable}.{year}.v0.nc"
    remote_file_path = f"{folder_path}/{file_name}"

    # Local file path
    local_file_path = os.path.join(local_destination, file_name)

    try:
        # Attempt to download the file
        print(f"Downloading {file_name} from {remote_file_path}...")
        with open(local_file_path, 'wb') as local_file:
            ftp.retrbinary(f"RETR {remote_file_path}", local_file.write)
        print(f"Successfully downloaded {file_name}.")
    except ftplib.error_perm as e:
        print(f"Error: File {file_name} not found on the server. ({e})")
        local_file_path = None
    finally:
        # Close the FTP connection
        ftp.quit()
        print("FTP connection closed.")

    return local_file_path

# %%
def process_year(model, year, variable, scenario, output_folder, gcp_bucket, ee_path):
    # Step 1: Download .nc File
    nc_file_path = download_model_files(model, year, variable, scenario, output_folder)

    if not nc_file_path:
        print(f"No .nc file for {year}. Skipping...")
        return

    # Step 2: Convert .nc to .tif
    ds = xr.open_dataset(nc_file_path)
    et = ds[variable]
    monthly_avg = et.resample(Time="1MS").mean(dim="Time")
    monthly_range = monthly_avg.max(dim="Time") - monthly_avg.min(dim="Time")

    # Handle lat/lon
    lat, lon = ds["Lat"].values, ds["Lon"].values
    lon2d, lat2d = np.meshgrid(lon, lat)
    lon_interp = np.linspace(lon2d.min(), lon2d.max(), monthly_range.shape[1])
    lat_interp = np.linspace(lat2d.min(), lat2d.max(), monthly_range.shape[0])
    lon_mesh, lat_mesh = np.meshgrid(lon_interp, lat_interp)
    lat_lon_points = np.array([lat2d.ravel(), lon2d.ravel()]).T
    monthly_range_flat = monthly_range.values.ravel()
    grid_data = griddata(lat_lon_points, monthly_range_flat, (lat_mesh, lon_mesh), method="linear")
    grid_data_flipped = np.flipud(np.where(np.isnan(grid_data), -9999, grid_data))

    transform = from_bounds(
        lon_interp.min(), lat_interp.min(), lon_interp.max(), lat_interp.max(),
        grid_data_flipped.shape[1], grid_data_flipped.shape[0]
    )
    tif_file = os.path.join(output_folder, f"{variable}_monthly_range_{year}.tif")
    with rasterio.open(
        tif_file, "w", driver="GTiff", height=grid_data_flipped.shape[0],
        width=grid_data_flipped.shape[1], count=1, dtype=grid_data_flipped.dtype,
        crs="EPSG:4326", transform=transform, nodata=-9999
    ) as dst:
        dst.write(grid_data_flipped, 1)
    print(f"GeoTIFF saved to {tif_file}")
""" 
    # Delete .nc File
    os.remove(nc_file_path)
    print(f"Deleted .nc file: {nc_file_path}")

    # Step 3: Save as COG
    cog_file = tif_file.replace(".tif", "_cog.tif")
    cog_cmd = f'gdal_translate {tif_file} {cog_file} -co TILED=YES -co COPY_SRC_OVERVIEWS=YES -co COMPRESS=LZW'
    subprocess.run(cog_cmd, shell=True)
    os.remove(tif_file)
    print(f"COG created and original GeoTIFF deleted: {cog_file}")

    # Step 4: Upload to GCP
    cp_cmd = f"gsutil cp {cog_file} gs://{gcp_bucket}/{os.path.basename(cog_file)}"
    subprocess.run(cp_cmd, shell=True)
    print(f"Uploaded COG to GCP: {cog_file}")

    gs_uri = f"gs://{gcp_bucket}/{os.path.basename(cog_file)}"
    asset_id = f"{ee_path}/vic_{variable}_range/{variable}_range_{year}".lower()


    # Step 5: Register Image in Collection
    ee_image = ee.Image.loadGeoTIFF(gs_uri)
    ee_image = ee_image.set(
            "system:time_start", ee.Date(f"{year}-01-01").millis(),
            "system:time_end", ee.Date(f"{year}-12-31").millis(),
            "model", model,
            "variable", variable,
            "scenario", scenario
        )
    task = ee.batch.Export.image.toAsset(
        image=ee_image,
        description=f"{variable}_{year}",
        assetId=asset_id,
        region=ee.Geometry.Rectangle(
            [lon_interp.min(), lat_interp.min(), lon_interp.max(), lat_interp.max()]
        ),
        scale=5000,
        maxPixels=1e13,
    )
    task.start()
    print(f"Earth Engine registration started for: {asset_id}")

    # Clean up
    os.remove(cog_file)
    print(f"Deleted local COG: {cog_file}") """

# %% [markdown]
# # Evapotranspiration - Actual (mm/day)
#
# *   List item
# *   List item

# %%
# Create the collection once
# Make sure the Image Collection ID matches your function calls
image_collection_id = "projects/pyregence-ee/assets/wrf-data/vic_et_range"
ee.data.createAsset({"type": "IMAGE_COLLECTION"}, image_collection_id)
# Out:
# {'type': 'IMAGE_COLLECTION',
#  'name': 'projects/pyregence-ee/assets/wrf-data/vic_et_range',
#  'id': 'projects/pyregence-ee/assets/wrf-data/vic_et_range',
#  'updateTime': '2024-12-18T19:20:19.060869Z'}

# %%
# Configuration
output_folder = "./output"
gcp_bucket = "cmip5-vic"
ee_path = "projects/pyregence-ee/assets/wrf-data"
start_year, end_year = 1990, 2030
model = "CanESM2"
variable = "ET"
scenario = "rcp85"



# Process each year
for year in range(start_year, end_year + 1):
    process_year(model, year, variable, scenario, output_folder, gcp_bucket, ee_path)
# Out:
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.1990.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.1990.v0.nc...
# Successfully downloaded ET.1990.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_1990.tif
# Deleted .nc file: ./output/ET.1990.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_1990_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_1990_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_1990
# Deleted local COG: ./output/ET_monthly_range_1990_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.1991.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.1991.v0.nc...
# Successfully downloaded ET.1991.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_1991.tif
# Deleted .nc file: ./output/ET.1991.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_1991_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_1991_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_1991
# Deleted local COG: ./output/ET_monthly_range_1991_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.1992.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.1992.v0.nc...
# Successfully downloaded ET.1992.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_1992.tif
# Deleted .nc file: ./output/ET.1992.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_1992_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_1992_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_1992
# Deleted local COG: ./output/ET_monthly_range_1992_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.1993.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.1993.v0.nc...
# Successfully downloaded ET.1993.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_1993.tif
# Deleted .nc file: ./output/ET.1993.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_1993_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_1993_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_1993
# Deleted local COG: ./output/ET_monthly_range_1993_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.1994.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.1994.v0.nc...
# Successfully downloaded ET.1994.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_1994.tif
# Deleted .nc file: ./output/ET.1994.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_1994_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_1994_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_1994
# Deleted local COG: ./output/ET_monthly_range_1994_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.1995.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.1995.v0.nc...
# Successfully downloaded ET.1995.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_1995.tif
# Deleted .nc file: ./output/ET.1995.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_1995_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_1995_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_1995
# Deleted local COG: ./output/ET_monthly_range_1995_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.1996.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.1996.v0.nc...
# Successfully downloaded ET.1996.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_1996.tif
# Deleted .nc file: ./output/ET.1996.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_1996_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_1996_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_1996
# Deleted local COG: ./output/ET_monthly_range_1996_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.1997.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.1997.v0.nc...
# Successfully downloaded ET.1997.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_1997.tif
# Deleted .nc file: ./output/ET.1997.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_1997_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_1997_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_1997
# Deleted local COG: ./output/ET_monthly_range_1997_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.1998.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.1998.v0.nc...
# Successfully downloaded ET.1998.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_1998.tif
# Deleted .nc file: ./output/ET.1998.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_1998_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_1998_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_1998
# Deleted local COG: ./output/ET_monthly_range_1998_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.1999.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.1999.v0.nc...
# Successfully downloaded ET.1999.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_1999.tif
# Deleted .nc file: ./output/ET.1999.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_1999_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_1999_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_1999
# Deleted local COG: ./output/ET_monthly_range_1999_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2000.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.2000.v0.nc...
# Successfully downloaded ET.2000.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2000.tif
# Deleted .nc file: ./output/ET.2000.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2000_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2000_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2000
# Deleted local COG: ./output/ET_monthly_range_2000_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2001.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.2001.v0.nc...
# Successfully downloaded ET.2001.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2001.tif
# Deleted .nc file: ./output/ET.2001.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2001_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2001_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2001
# Deleted local COG: ./output/ET_monthly_range_2001_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2002.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.2002.v0.nc...
# Successfully downloaded ET.2002.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2002.tif
# Deleted .nc file: ./output/ET.2002.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2002_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2002_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2002
# Deleted local COG: ./output/ET_monthly_range_2002_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2003.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.2003.v0.nc...
# Successfully downloaded ET.2003.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2003.tif
# Deleted .nc file: ./output/ET.2003.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2003_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2003_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2003
# Deleted local COG: ./output/ET_monthly_range_2003_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2004.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.2004.v0.nc...
# Successfully downloaded ET.2004.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2004.tif
# Deleted .nc file: ./output/ET.2004.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2004_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2004_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2004
# Deleted local COG: ./output/ET_monthly_range_2004_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2005.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/ET.2005.v0.nc...
# Successfully downloaded ET.2005.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2005.tif
# Deleted .nc file: ./output/ET.2005.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2005_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2005_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2005
# Deleted local COG: ./output/ET_monthly_range_2005_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2006.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2006.v0.nc...
# Successfully downloaded ET.2006.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2006.tif
# Deleted .nc file: ./output/ET.2006.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2006_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2006_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2006
# Deleted local COG: ./output/ET_monthly_range_2006_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2007.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2007.v0.nc...
# Successfully downloaded ET.2007.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2007.tif
# Deleted .nc file: ./output/ET.2007.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2007_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2007_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2007
# Deleted local COG: ./output/ET_monthly_range_2007_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2008.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2008.v0.nc...
# Successfully downloaded ET.2008.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2008.tif
# Deleted .nc file: ./output/ET.2008.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2008_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2008_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2008
# Deleted local COG: ./output/ET_monthly_range_2008_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2009.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2009.v0.nc...
# Successfully downloaded ET.2009.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2009.tif
# Deleted .nc file: ./output/ET.2009.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2009_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2009_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2009
# Deleted local COG: ./output/ET_monthly_range_2009_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2010.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2010.v0.nc...
# Successfully downloaded ET.2010.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2010.tif
# Deleted .nc file: ./output/ET.2010.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2010_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2010_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2010
# Deleted local COG: ./output/ET_monthly_range_2010_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2011.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2011.v0.nc...
# Successfully downloaded ET.2011.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2011.tif
# Deleted .nc file: ./output/ET.2011.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2011_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2011_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2011
# Deleted local COG: ./output/ET_monthly_range_2011_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2012.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2012.v0.nc...
# Successfully downloaded ET.2012.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2012.tif
# Deleted .nc file: ./output/ET.2012.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2012_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2012_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2012
# Deleted local COG: ./output/ET_monthly_range_2012_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2013.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2013.v0.nc...
# Successfully downloaded ET.2013.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2013.tif
# Deleted .nc file: ./output/ET.2013.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2013_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2013_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2013
# Deleted local COG: ./output/ET_monthly_range_2013_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2014.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2014.v0.nc...
# Successfully downloaded ET.2014.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2014.tif
# Deleted .nc file: ./output/ET.2014.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2014_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2014_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2014
# Deleted local COG: ./output/ET_monthly_range_2014_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2015.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2015.v0.nc...
# Successfully downloaded ET.2015.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2015.tif
# Deleted .nc file: ./output/ET.2015.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2015_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2015_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2015
# Deleted local COG: ./output/ET_monthly_range_2015_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2016.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2016.v0.nc...
# Successfully downloaded ET.2016.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2016.tif
# Deleted .nc file: ./output/ET.2016.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2016_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2016_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2016
# Deleted local COG: ./output/ET_monthly_range_2016_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2017.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2017.v0.nc...
# Successfully downloaded ET.2017.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2017.tif
# Deleted .nc file: ./output/ET.2017.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2017_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2017_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2017
# Deleted local COG: ./output/ET_monthly_range_2017_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2018.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2018.v0.nc...
# Successfully downloaded ET.2018.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2018.tif
# Deleted .nc file: ./output/ET.2018.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2018_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2018_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2018
# Deleted local COG: ./output/ET_monthly_range_2018_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2019.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2019.v0.nc...
# Successfully downloaded ET.2019.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2019.tif
# Deleted .nc file: ./output/ET.2019.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2019_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2019_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2019
# Deleted local COG: ./output/ET_monthly_range_2019_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2020.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2020.v0.nc...
# Successfully downloaded ET.2020.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2020.tif
# Deleted .nc file: ./output/ET.2020.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2020_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2020_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2020
# Deleted local COG: ./output/ET_monthly_range_2020_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2021.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2021.v0.nc...
# Successfully downloaded ET.2021.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2021.tif
# Deleted .nc file: ./output/ET.2021.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2021_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2021_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2021
# Deleted local COG: ./output/ET_monthly_range_2021_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2022.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2022.v0.nc...
# Successfully downloaded ET.2022.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2022.tif
# Deleted .nc file: ./output/ET.2022.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2022_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2022_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2022
# Deleted local COG: ./output/ET_monthly_range_2022_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2023.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2023.v0.nc...
# Successfully downloaded ET.2023.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2023.tif
# Deleted .nc file: ./output/ET.2023.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2023_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2023_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2023
# Deleted local COG: ./output/ET_monthly_range_2023_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2024.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2024.v0.nc...
# Successfully downloaded ET.2024.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2024.tif
# Deleted .nc file: ./output/ET.2024.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2024_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2024_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2024
# Deleted local COG: ./output/ET_monthly_range_2024_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2025.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2025.v0.nc...
# Successfully downloaded ET.2025.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2025.tif
# Deleted .nc file: ./output/ET.2025.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2025_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2025_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2025
# Deleted local COG: ./output/ET_monthly_range_2025_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2026.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2026.v0.nc...
# Successfully downloaded ET.2026.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2026.tif
# Deleted .nc file: ./output/ET.2026.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2026_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2026_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2026
# Deleted local COG: ./output/ET_monthly_range_2026_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2027.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2027.v0.nc...
# Successfully downloaded ET.2027.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2027.tif
# Deleted .nc file: ./output/ET.2027.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2027_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2027_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2027
# Deleted local COG: ./output/ET_monthly_range_2027_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2028.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2028.v0.nc...
# Successfully downloaded ET.2028.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2028.tif
# Deleted .nc file: ./output/ET.2028.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2028_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2028_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2028
# Deleted local COG: ./output/ET_monthly_range_2028_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2029.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2029.v0.nc...
# Successfully downloaded ET.2029.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2029.tif
# Deleted .nc file: ./output/ET.2029.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2029_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2029_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2029
# Deleted local COG: ./output/ET_monthly_range_2029_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading ET.2030.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/ET.2030.v0.nc...
# Successfully downloaded ET.2030.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/ET_monthly_range_2030.tif
# Deleted .nc file: ./output/ET.2030.v0.nc
# COG created and original GeoTIFF deleted: ./output/ET_monthly_range_2030_cog.tif
# Uploaded COG to GCP: ./output/ET_monthly_range_2030_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_et_range/et_range_2030
# Deleted local COG: ./output/ET_monthly_range_2030_cog.tif

# %% [markdown]
# # Evapotranspiration - Potential, natural veg (mm/day)

# %%
# Create the collection once
# Make sure the Image Collection ID matches your function calls
image_collection_id = "projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range"
ee.data.createAsset({"type": "IMAGE_COLLECTION"}, image_collection_id)
# Out:
# {'type': 'IMAGE_COLLECTION',
#  'name': 'projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range',
#  'id': 'projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range',
#  'updateTime': '2024-12-18T20:01:57.698368Z'}

# %%
# Configuration
output_folder = "./output"
gcp_bucket = "cmip5-vic"
ee_path = "projects/pyregence-ee/assets/wrf-data"
start_year, end_year = 1990, 2030
model = "CanESM2"
variable = "pet_natveg"
scenario = "rcp85"



# Process each year
for year in range(start_year, end_year + 1):
    process_year(model, year, variable, scenario, output_folder, gcp_bucket, ee_path)
# Out:
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.1990.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.1990.v0.nc...
# Successfully downloaded pet_natveg.1990.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_1990.tif
# Deleted .nc file: ./output/pet_natveg.1990.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_1990_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_1990_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_1990
# Deleted local COG: ./output/pet_natveg_monthly_range_1990_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.1991.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.1991.v0.nc...
# Successfully downloaded pet_natveg.1991.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_1991.tif
# Deleted .nc file: ./output/pet_natveg.1991.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_1991_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_1991_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_1991
# Deleted local COG: ./output/pet_natveg_monthly_range_1991_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.1992.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.1992.v0.nc...
# Successfully downloaded pet_natveg.1992.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_1992.tif
# Deleted .nc file: ./output/pet_natveg.1992.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_1992_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_1992_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_1992
# Deleted local COG: ./output/pet_natveg_monthly_range_1992_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.1993.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.1993.v0.nc...
# Successfully downloaded pet_natveg.1993.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_1993.tif
# Deleted .nc file: ./output/pet_natveg.1993.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_1993_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_1993_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_1993
# Deleted local COG: ./output/pet_natveg_monthly_range_1993_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.1994.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.1994.v0.nc...
# Successfully downloaded pet_natveg.1994.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_1994.tif
# Deleted .nc file: ./output/pet_natveg.1994.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_1994_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_1994_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_1994
# Deleted local COG: ./output/pet_natveg_monthly_range_1994_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.1995.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.1995.v0.nc...
# Successfully downloaded pet_natveg.1995.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_1995.tif
# Deleted .nc file: ./output/pet_natveg.1995.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_1995_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_1995_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_1995
# Deleted local COG: ./output/pet_natveg_monthly_range_1995_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.1996.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.1996.v0.nc...
# Successfully downloaded pet_natveg.1996.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_1996.tif
# Deleted .nc file: ./output/pet_natveg.1996.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_1996_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_1996_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_1996
# Deleted local COG: ./output/pet_natveg_monthly_range_1996_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.1997.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.1997.v0.nc...
# Successfully downloaded pet_natveg.1997.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_1997.tif
# Deleted .nc file: ./output/pet_natveg.1997.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_1997_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_1997_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_1997
# Deleted local COG: ./output/pet_natveg_monthly_range_1997_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.1998.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.1998.v0.nc...
# Successfully downloaded pet_natveg.1998.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_1998.tif
# Deleted .nc file: ./output/pet_natveg.1998.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_1998_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_1998_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_1998
# Deleted local COG: ./output/pet_natveg_monthly_range_1998_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.1999.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.1999.v0.nc...
# Successfully downloaded pet_natveg.1999.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_1999.tif
# Deleted .nc file: ./output/pet_natveg.1999.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_1999_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_1999_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_1999
# Deleted local COG: ./output/pet_natveg_monthly_range_1999_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2000.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.2000.v0.nc...
# Successfully downloaded pet_natveg.2000.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2000.tif
# Deleted .nc file: ./output/pet_natveg.2000.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2000_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2000_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2000
# Deleted local COG: ./output/pet_natveg_monthly_range_2000_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2001.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.2001.v0.nc...
# Successfully downloaded pet_natveg.2001.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2001.tif
# Deleted .nc file: ./output/pet_natveg.2001.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2001_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2001_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2001
# Deleted local COG: ./output/pet_natveg_monthly_range_2001_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2002.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.2002.v0.nc...
# Successfully downloaded pet_natveg.2002.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2002.tif
# Deleted .nc file: ./output/pet_natveg.2002.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2002_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2002_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2002
# Deleted local COG: ./output/pet_natveg_monthly_range_2002_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2003.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.2003.v0.nc...
# Successfully downloaded pet_natveg.2003.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2003.tif
# Deleted .nc file: ./output/pet_natveg.2003.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2003_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2003_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2003
# Deleted local COG: ./output/pet_natveg_monthly_range_2003_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2004.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.2004.v0.nc...
# Successfully downloaded pet_natveg.2004.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2004.tif
# Deleted .nc file: ./output/pet_natveg.2004.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2004_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2004_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2004
# Deleted local COG: ./output/pet_natveg_monthly_range_2004_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2005.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.historical.netcdf/pet_natveg.2005.v0.nc...
# Successfully downloaded pet_natveg.2005.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2005.tif
# Deleted .nc file: ./output/pet_natveg.2005.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2005_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2005_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2005
# Deleted local COG: ./output/pet_natveg_monthly_range_2005_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2006.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2006.v0.nc...
# Successfully downloaded pet_natveg.2006.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2006.tif
# Deleted .nc file: ./output/pet_natveg.2006.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2006_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2006_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2006
# Deleted local COG: ./output/pet_natveg_monthly_range_2006_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2007.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2007.v0.nc...
# Successfully downloaded pet_natveg.2007.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2007.tif
# Deleted .nc file: ./output/pet_natveg.2007.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2007_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2007_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2007
# Deleted local COG: ./output/pet_natveg_monthly_range_2007_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2008.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2008.v0.nc...
# Successfully downloaded pet_natveg.2008.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2008.tif
# Deleted .nc file: ./output/pet_natveg.2008.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2008_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2008_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2008
# Deleted local COG: ./output/pet_natveg_monthly_range_2008_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2009.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2009.v0.nc...
# Successfully downloaded pet_natveg.2009.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2009.tif
# Deleted .nc file: ./output/pet_natveg.2009.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2009_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2009_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2009
# Deleted local COG: ./output/pet_natveg_monthly_range_2009_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2010.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2010.v0.nc...
# Successfully downloaded pet_natveg.2010.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2010.tif
# Deleted .nc file: ./output/pet_natveg.2010.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2010_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2010_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2010
# Deleted local COG: ./output/pet_natveg_monthly_range_2010_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2011.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2011.v0.nc...
# Successfully downloaded pet_natveg.2011.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2011.tif
# Deleted .nc file: ./output/pet_natveg.2011.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2011_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2011_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2011
# Deleted local COG: ./output/pet_natveg_monthly_range_2011_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2012.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2012.v0.nc...
# Successfully downloaded pet_natveg.2012.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2012.tif
# Deleted .nc file: ./output/pet_natveg.2012.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2012_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2012_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2012
# Deleted local COG: ./output/pet_natveg_monthly_range_2012_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2013.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2013.v0.nc...
# Successfully downloaded pet_natveg.2013.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2013.tif
# Deleted .nc file: ./output/pet_natveg.2013.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2013_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2013_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2013
# Deleted local COG: ./output/pet_natveg_monthly_range_2013_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2014.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2014.v0.nc...
# Successfully downloaded pet_natveg.2014.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2014.tif
# Deleted .nc file: ./output/pet_natveg.2014.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2014_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2014_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2014
# Deleted local COG: ./output/pet_natveg_monthly_range_2014_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2015.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2015.v0.nc...
# Successfully downloaded pet_natveg.2015.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2015.tif
# Deleted .nc file: ./output/pet_natveg.2015.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2015_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2015_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2015
# Deleted local COG: ./output/pet_natveg_monthly_range_2015_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2016.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2016.v0.nc...
# Successfully downloaded pet_natveg.2016.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2016.tif
# Deleted .nc file: ./output/pet_natveg.2016.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2016_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2016_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2016
# Deleted local COG: ./output/pet_natveg_monthly_range_2016_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2017.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2017.v0.nc...
# Successfully downloaded pet_natveg.2017.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2017.tif
# Deleted .nc file: ./output/pet_natveg.2017.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2017_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2017_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2017
# Deleted local COG: ./output/pet_natveg_monthly_range_2017_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2018.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2018.v0.nc...
# Successfully downloaded pet_natveg.2018.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2018.tif
# Deleted .nc file: ./output/pet_natveg.2018.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2018_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2018_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2018
# Deleted local COG: ./output/pet_natveg_monthly_range_2018_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2019.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2019.v0.nc...
# Successfully downloaded pet_natveg.2019.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2019.tif
# Deleted .nc file: ./output/pet_natveg.2019.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2019_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2019_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2019
# Deleted local COG: ./output/pet_natveg_monthly_range_2019_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2020.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2020.v0.nc...
# Successfully downloaded pet_natveg.2020.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2020.tif
# Deleted .nc file: ./output/pet_natveg.2020.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2020_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2020_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2020
# Deleted local COG: ./output/pet_natveg_monthly_range_2020_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2021.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2021.v0.nc...
# Successfully downloaded pet_natveg.2021.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2021.tif
# Deleted .nc file: ./output/pet_natveg.2021.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2021_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2021_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2021
# Deleted local COG: ./output/pet_natveg_monthly_range_2021_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2022.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2022.v0.nc...
# Successfully downloaded pet_natveg.2022.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2022.tif
# Deleted .nc file: ./output/pet_natveg.2022.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2022_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2022_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2022
# Deleted local COG: ./output/pet_natveg_monthly_range_2022_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2023.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2023.v0.nc...
# Successfully downloaded pet_natveg.2023.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2023.tif
# Deleted .nc file: ./output/pet_natveg.2023.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2023_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2023_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2023
# Deleted local COG: ./output/pet_natveg_monthly_range_2023_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2024.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2024.v0.nc...
# Successfully downloaded pet_natveg.2024.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2024.tif
# Deleted .nc file: ./output/pet_natveg.2024.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2024_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2024_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2024
# Deleted local COG: ./output/pet_natveg_monthly_range_2024_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2025.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2025.v0.nc...
# Successfully downloaded pet_natveg.2025.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2025.tif
# Deleted .nc file: ./output/pet_natveg.2025.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2025_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2025_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2025
# Deleted local COG: ./output/pet_natveg_monthly_range_2025_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2026.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2026.v0.nc...
# Successfully downloaded pet_natveg.2026.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2026.tif
# Deleted .nc file: ./output/pet_natveg.2026.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2026_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2026_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2026
# Deleted local COG: ./output/pet_natveg_monthly_range_2026_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2027.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2027.v0.nc...
# Successfully downloaded pet_natveg.2027.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2027.tif
# Deleted .nc file: ./output/pet_natveg.2027.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2027_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2027_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2027
# Deleted local COG: ./output/pet_natveg_monthly_range_2027_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2028.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2028.v0.nc...
# Successfully downloaded pet_natveg.2028.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2028.tif
# Deleted .nc file: ./output/pet_natveg.2028.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2028_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2028_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2028
# Deleted local COG: ./output/pet_natveg_monthly_range_2028_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2029.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2029.v0.nc...
# Successfully downloaded pet_natveg.2029.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2029.tif
# Deleted .nc file: ./output/pet_natveg.2029.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2029_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2029_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2029
# Deleted local COG: ./output/pet_natveg_monthly_range_2029_cog.tif
# Connected to gdo-dcp.ucllnl.org.
# Downloading pet_natveg.2030.v0.nc from /pub/dcp/archive/cmip5/loca_hydro/LOCA_VIC_dpierce_2017-02-28/CanESM2/vic_output.rcp85.netcdf/pet_natveg.2030.v0.nc...
# Successfully downloaded pet_natveg.2030.v0.nc.
# FTP connection closed.
# GeoTIFF saved to ./output/pet_natveg_monthly_range_2030.tif
# Deleted .nc file: ./output/pet_natveg.2030.v0.nc
# COG created and original GeoTIFF deleted: ./output/pet_natveg_monthly_range_2030_cog.tif
# Uploaded COG to GCP: ./output/pet_natveg_monthly_range_2030_cog.tif
# Earth Engine registration started for: projects/pyregence-ee/assets/wrf-data/vic_pet_natveg_range/pet_natveg_range_2030
# Deleted local COG: ./output/pet_natveg_monthly_range_2030_cog.tif
